# %%
import matplotlib.pyplot as plt

Date = ["20/07","21/07","22/07","23/07","24/07","25/07","26/07","27/07","28/07","29/07","30/07","31/07","01/08","02/08","03/08","04/08","05/08","06/08","07/08","08/08","09/08","10/08","11/08","12/08"]
Vertical_Muons = [0.003231292517,0.002551020408,0.00306122449,float('NaN'),float('NaN'),0.003401360544,0.003571428571,0.003571428571,0.003401360544,0.002551020408,float('NaN'),float('NaN'),0.00425170068,0.003571428571,0.002551020408,0.002551020408,0.002551020408,float('NaN'),float('NaN'),float('NaN'),0.00306122449,0.003571428571,0.002551020408,0.001700680272]
Total_Muons = [0.004761904762,0.003911564626,0.004081632653,float('NaN'),float('NaN'),0.005272108844,0.00731292517,0.004421768707,0.005952380952,0.003911564626,float('NaN'),float('NaN'),0.005612244898,0.004761904762,0.002891156463,0.003231292517,0.004081632653,float('NaN'),float('NaN'),float('NaN'),0.005102040816,0.005102040816,0.003911564626,0.002891156463]
Alphas = [0.001700680272,0.002380952381,0.002040816327,float('NaN'),float('NaN'),0.001360544218,0.001700680272,0.00119047619,0.001360544218,0.002210884354,float('NaN'),float('NaN'),0.001870748299,0.002210884354,0.001870748299,0.001870748299,0.001360544218,float('NaN'),float('NaN'),float('NaN'),0.001530612245,0.002040816327,0.001700680272,0.001700680272]
Electrons = [0.008843537415,0.01037414966,0.009353741497,float('NaN'),float('NaN'),0.01054421769,0.008673469388,0.009523809524,0.01037414966,0.009693877551,float('NaN'),float('NaN'),0.007993197279,0.009353741497,0.01224489796,0.01173469388,0.009523809524,float('NaN'),float('NaN'),float('NaN'),0.01071428571,0.01071428571,0.01088435374,0.01020408163]
MuonsAndElectrons = [0.01360544218,0.01428571429,0.01343537415,float('NaN'),float('NaN'),0.01581632653,0.01598639456,0.01394557823,0.01632653061,0.01360544218,float('NaN'),float('NaN'),0.01360544218,0.01411564626,0.01513605442,0.01496598639,0.01360544218,float('NaN'),float('NaN'),float('NaN'),0.01581632653,0.01581632653,0.01479591837,0.0130952381]

#error
Vertical_Muons_Error = [0.0007413093441,0.0006586706371,0.0007215375318,float('NaN'),float('NaN'),0.0007605673393,0.000779349608,0.000779349608,0.0007605673393,0.0006586706371,float('NaN'),float('NaN'),0.0008503401361,0.000779349608,0.0006586706371,0.0006586706371,0.0006586706371,float('NaN'),float('NaN'),float('NaN'),0.0007215375318,0.000779349608,0.0006586706371,0.0005378023232]
Total_Muons_Error = [0.0008999154119,0.000815617606,0.0008331597765,float('NaN'),float('NaN'),0.0009468987012,0.001115210633,0.0008671801894,0.001006136018,0.000815617606,float('NaN'),float('NaN'),0.0009769664365,0.0008999154119,0.0007012084397,0.0007413093441,0.0008331597765,float('NaN'),float('NaN'),float('NaN'),0.0009315009481,0.0009315009481,0.000815617606,0.0007012084397]
Alphas_Error = [0.0005378023232,0.0006363362903,0.0005891329277,float('NaN'),float('NaN'),0.0004810250212,0.0005378023232,0.000449957706,0.0004810250212,0.0006131889924,float('NaN'),float('NaN'),0.0005640518351,0.0006131889924,0.0005640518351,0.0005640518351,0.0004810250212,float('NaN'),float('NaN'),float('NaN'),0.0005102040816,0.0005891329277,0.0005378023232,0.0005378023232]
Electrons_Error = [0.001226377985,0.001328273754,0.001261258246,float('NaN'),float('NaN'),0.001339116985,0.001214528644,0.001272672581,0.001328273754,0.001283985448,float('NaN'),float('NaN'),0.001165927653,0.001261258246,0.001443075064,0.001412691133,0.001272672581,float('NaN'),float('NaN'),float('NaN'),0.001349873118,0.001349873118,0.001360544218,0.001317341274]
MuonsAndElectrons_Error = [0.001521134679,0.001558699216,0.00151159769,float('NaN'),float('NaN'),0.00164007666,0.0016488707,0.001540031486,0.001666319553,0.001521134679,float('NaN'),float('NaN'),0.001521134679,0.001549393466,0.00160441856,0.00159537951,0.001521134679,float('NaN'),float('NaN'),float('NaN'),0.00164007666,0.00164007666,0.001586288955,0.001492340882]

Flux = [Vertical_Muons, Total_Muons, Alphas, Electrons, MuonsAndElectrons]
lab = ["Vertical Muons","Total Muons","Alphas","Electrons","Muon+Electrons"]
col = ["royalblue","orange","green","red","purple"]

plt.figure(figsize=(12,3.5))
for z in range(len(Flux)):
    plt.plot(Date, Flux[z], label=lab[z], color=col[z])
    
plt.ylim(0,0.02)
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.grid()
plt.xlabel("Time (Days)")
plt.ylabel("Flux (particles/cm^2/s)")
plt.legend(loc="upper left",ncol=5)
plt.title("Flux Over Time")
plt.tight_layout()
plt.errorbar(x=Date, y=Vertical_Muons, yerr=Vertical_Muons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Total_Muons, yerr=Total_Muons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Alphas, yerr=Alphas_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Electrons, yerr=Electrons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=MuonsAndElectrons, yerr=MuonsAndElectrons_Error, capsize=4, fmt=".")
# Out:
# <ErrorbarContainer object of 3 artists>
