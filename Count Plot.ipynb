# %%
import matplotlib.pyplot as plt

Date = ["20/07","21/07","22/07","23/07","24/07","25/07","26/07","27/07","28/07","29/07","30/07","31/07","01/08","02/08","03/08","04/08","05/08","06/08","07/08","08/08","09/08","10/08","11/08","12/08"]
Vertical_Muons = [19,15,18,float('NaN'),float('NaN'),20,21,21,20,15,float('NaN'),float('NaN'),25,21,15,15,15,float('NaN'),float('NaN'),float('NaN'),18,21,15,10]
Total_Muons = [28,23,24,float('NaN'),float('NaN'),31,43,26,35,23,float('NaN'),float('NaN'),33,28,17,19,24,float('NaN'),float('NaN'),float('NaN'),30,30,23,17]
Alphas = [10,14,12,float('NaN'),float('NaN'),8,10,7,8,13,float('NaN'),float('NaN'),11,13,11,11,8,float('NaN'),float('NaN'),float('NaN'),9,12,10,10]
Electrons = [52,61,55,float('NaN'),float('NaN'),62,51,56,61,57,float('NaN'),float('NaN'),47,55,72,69,56,float('NaN'),float('NaN'),float('NaN'),63,63,64,60]
MuonsAndElectrons = [80,84,79,float('NaN'),float('NaN'),93,94,82,96,80,float('NaN'),float('NaN'),80,83,89,88,80,float('NaN'),float('NaN'),float('NaN'),93,93,87,77]

#error
Vertical_Muons_Error = [4.358898944,3.872983346,4.242640687,float('NaN'),float('NaN'),4.472135955,4.582575695,4.582575695,4.472135955,3.872983346,float('NaN'),float('NaN'),5,4.582575695,3.872983346,3.872983346,3.872983346,float('NaN'),float('NaN'),float('NaN'),4.242640687,4.582575695,3.872983346,3.16227766]
Total_Muons_Error = [5.291502622,4.795831523,4.898979486,float('NaN'),float('NaN'),5.567764363,6.557438524,5.099019514,5.916079783,4.795831523,float('NaN'),float('NaN'),5.744562647,5.291502622,4.123105626,4.358898944,4.898979486,float('NaN'),float('NaN'),float('NaN'),5.477225575,5.477225575,4.795831523,4.123105626]
Alphas_Error = [3.16227766,3.741657387,3.464101615,float('NaN'),float('NaN'),2.828427125,3.16227766,2.645751311,2.828427125,3.605551275,float('NaN'),float('NaN'),3.31662479,3.605551275,3.31662479,3.31662479,2.828427125,float('NaN'),float('NaN'),float('NaN'),3,3.464101615,3.16227766,3.16227766]
Electrons_Error = [7.211102551,7.810249676,7.416198487,float('NaN'),float('NaN'),7.874007874,7.141428429,7.483314774,7.810249676,7.549834435,float('NaN'),float('NaN'),6.8556546,7.416198487,8.485281374,8.306623863,7.483314774,float('NaN'),float('NaN'),float('NaN'),7.937253933,7.937253933,8,7.745966692]
MuonsAndElectrons_Error = [8.94427191,9.16515139,8.888194417,float('NaN'),float('NaN'),9.643650761,9.695359715,9.055385138,9.797958971,8.94427191,float('NaN'),float('NaN'),8.94427191,9.110433579,9.433981132,9.38083152,8.94427191,float('NaN'),float('NaN'),float('NaN'),9.643650761,9.643650761,9.327379053,8.774964387]

Count = [Vertical_Muons, Total_Muons, Alphas, Electrons, MuonsAndElectrons]
lab = ["Vertical Muons","Total Muons","Alphas","Electrons","Muon+Electrons"]
col = ["royalblue","orange","green","red","purple"]

plt.figure(figsize=(12,3.5))
for z in range(len(Count)):
    plt.plot(Date, Count[z], label=lab[z], color=col[z])
    
plt.ylim(0,130)
plt.grid()
plt.xlabel("Time (Days)")
plt.ylabel("Count")
plt.legend(loc="upper left",ncol=5)
plt.title("Count Over Time")
plt.tight_layout()
plt.errorbar(x=Date, y=Vertical_Muons, yerr=Vertical_Muons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Total_Muons, yerr=Total_Muons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Alphas, yerr=Alphas_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=Electrons, yerr=Electrons_Error, capsize=4, fmt=".")
plt.errorbar(x=Date, y=MuonsAndElectrons, yerr=MuonsAndElectrons_Error, capsize=4, fmt=".")
# Out:
# <ErrorbarContainer object of 3 artists>
